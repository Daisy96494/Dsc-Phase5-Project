# %%
import pandas as pd

# %%
df = pd.read_csv('isd-history.csv')
df
# Out:
#          USAF   WBAN                                       STATION NAME CTRY  \
# 0      007018  99999                                         WXPOD 7018  NaN
# 1      007026  99999                                         WXPOD 7026   AF
# 2      007070  99999                                         WXPOD 7070   AF
# 3      008260  99999                                          WXPOD8270  NaN
# 4      008268  99999                                          WXPOD8278   AF
# ...       ...    ...                                                ...  ...
# 29654  A07355    241                          VIROQUA MUNICIPAL AIRPORT   US
# 29655  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF THE PRAIRIE AIRPORT   US
# 29656  A07359    240                               IONIA COUNTY AIRPORT   US
# 29657  A51255    445                        DEMOPOLIS MUNICIPAL AIRPORT   US
# 29658  A51256    451       BRANSON WEST MUNICIPAL EMERSON FIELD AIRPORT   US
#
# ...

# %%
df.columns
# Out:
# Index(['USAF', 'WBAN', 'STATION NAME', 'CTRY', 'STATE', 'ICAO', 'LAT', 'LON',
#        'ELEV(M)', 'BEGIN', 'END'],
#       dtype='object')

# %%
df['CTRY'].unique()
# Out:
# array([nan, 'AF', 'NO', 'SV', 'FO', 'SW', 'SZ', 'FI', 'UK', 'IM', 'GB',
#        'EI', 'IC', 'GL', 'DA', 'WA', 'NL', 'BE', 'LU', 'CH', 'LS', 'FR',
#        'PO', 'SP', 'GI', 'AZ', 'PT', 'CV', 'GM', 'GQ', 'AU', 'IT', 'EZ',
#        'LO', 'PL', 'HU', 'SI', 'HR', 'RI', 'EG', 'KV', 'BK', 'MJ', 'MK',
#        'XK', 'RS', 'AL', 'RO', 'BU', 'BG', 'MT', 'GR', 'TU', 'TR', 'CY',
#        'RU', 'EN', 'BO', 'LG', 'LH', 'KZ', 'UP', 'MD', 'AM', 'GG', 'UZ',
#        'KG', 'AJ', 'TX', 'TI', 'SY', 'LE', 'IS', 'JO', 'SA', 'KU', 'BA',
#        'QA', 'AE', 'YM', 'MU', 'IZ', 'IR', 'OM', 'PK', 'IN', 'BT', 'CE',
#        'MV', 'MG', 'NP', 'HK', 'MC', 'TW', 'KN', 'KS', 'KR', 'JA', 'JP',
#        'BM', 'TH', 'MY', 'SN', 'LA', 'VM', 'CB', 'CN', 'CP', 'EH', 'WI',
#        'MO', 'MR', 'MB', 'AG', 'LY', 'DZ', 'TS', 'TN', 'NG', 'ML', 'SG',
#        'GA', 'PU', 'GV', 'SL', 'SH', 'AY', 'TP', 'IO', 'FS', 'JU', 'RE',
#        'EU', 'MP', 'TE', 'US', 'SU', 'OD', 'ET', 'ER', 'DJ', 'BP', 'SO',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29659 entries, 0 to 29658
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   USAF          29659 non-null  object
#  1   WBAN          29659 non-null  int64
#  2   STATION NAME  28868 non-null  object
#  3   CTRY          28765 non-null  object
#  4   STATE         6534 non-null   object
#  5   ICAO          10840 non-null  object
#  6   LAT           28473 non-null  float64
#  7   LON           28472 non-null  float64
#  8   ELEV(M)       28369 non-null  float64
#  9   BEGIN         29659 non-null  int64
#  10  END           29659 non-null  int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.5+ MB

# %%
fdf = df[df['LON'].notnull()]
fdf
# Out:
#          USAF   WBAN                                       STATION NAME CTRY  \
# 0      007018  99999                                         WXPOD 7018  NaN
# 1      007026  99999                                         WXPOD 7026   AF
# 2      007070  99999                                         WXPOD 7070   AF
# 3      008260  99999                                          WXPOD8270  NaN
# 4      008268  99999                                          WXPOD8278   AF
# ...       ...    ...                                                ...  ...
# 29654  A07355    241                          VIROQUA MUNICIPAL AIRPORT   US
# 29655  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF THE PRAIRIE AIRPORT   US
# 29656  A07359    240                               IONIA COUNTY AIRPORT   US
# 29657  A51255    445                        DEMOPOLIS MUNICIPAL AIRPORT   US
# 29658  A51256    451       BRANSON WEST MUNICIPAL EMERSON FIELD AIRPORT   US
#
# ...

# %%
fdf['LAT'].isnull().value_counts()
# Out:
# LAT
# False    28472
# Name: count, dtype: int64

# %%
rescols = ['USAF', 'WBAN', 'STATION NAME', 'LAT', 'LON']

# %%
ffdf = fdf[rescols]
ffdf
# Out:
#          USAF   WBAN                                       STATION NAME  \
# 0      007018  99999                                         WXPOD 7018
# 1      007026  99999                                         WXPOD 7026
# 2      007070  99999                                         WXPOD 7070
# 3      008260  99999                                          WXPOD8270
# 4      008268  99999                                          WXPOD8278
# ...       ...    ...                                                ...
# 29654  A07355    241                          VIROQUA MUNICIPAL AIRPORT
# 29655  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF THE PRAIRIE AIRPORT
# 29656  A07359    240                               IONIA COUNTY AIRPORT
# 29657  A51255    445                        DEMOPOLIS MUNICIPAL AIRPORT
# 29658  A51256    451       BRANSON WEST MUNICIPAL EMERSON FIELD AIRPORT
#
#           LAT     LON
# 0       0.000   0.000
# 1       0.000   0.000
# 2       0.000   0.000
# ...
